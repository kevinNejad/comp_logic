# %%
import requests

# %%
## Look https://github.com/commonsense/conceptnet5/wiki/Relations 
'''
IsA: car -> vehicle; Chicago -> city
PartOf: gearshit -> car
HasA: bird -> wing; pen -> ink
UsedFor: bridge -> cross water
CapableOf: knife -> cut
AtLocation: butter -> refrigerator; London -> UK
Causes: exercise -> sweat
HasProperty: ice -> cold
Desires: person -> love
CreatedBy: cake -> bake
CausesDesire: having no food -> go to store
MadeOf: bottle -> plastic
'''
relations = ['IsA','PartOf','HasA','UsedFor','CapableOf','AtLocation',
            'Causes','HasProperty','Desires','CreatedBy','CausesDesire','MadeOf']

# %%
API_URI = 'http://api.conceptnet.io/'
EN = 'en'
def get_data(target, relations):
    data={}
    for rel in relations:
        query = 'query?start=/c/{}/{}&rel=/r/{}&limit=1000'.format(EN,target,rel)
        obj = requests.get(API_URI+query).json()
        
        # check if such a relation exist
        if len(obj['edges']) == 0:
            continue
        info = extract_info(obj)
        data[rel] = info
    return data

def extract_info(obj):
    labels = []
    for edge in obj['edges']:
        labels.append(edge['end']['label'])
        
    return labels

# %%
data = get_data('doctor', relations)

# %%
data
# Out:
# {'IsA': ['play',
#   'a man of science',
#   'theologian',
#   'scholar',
#   'medical practitioner',
#   'helping the woman',
#   'expert',
#   "examining patient's record",
#   'prescriber',
#   'worker',
#   'someone who treats sick people',
#   'medical school graduate',
#   'a professional',
#   'an educated person',
#   'person',
#   'one job',
#   'licensed professional',
#   'medic',
#   'fictional character'],
#  'PartOf': ['doctor who'],
#  'HasA': ['studied medicine', 'very nice eyes', 'had many years of education'],
#  'UsedFor': ['heal',
#   "diagnosing peoples' problems",
#   'providing expert information',
#   'maintaining health',
#   "curing a person's disease",
#   'making you feel better',
#   'visiting when ill',
#   'treating a patient',
#   'healing',
#   'healing the sick',
#   'keeping hospitals running',
#   'funding the drug industry',
#   'healing the injured',
#   'employing nurses',
#   'diagnose illnesses',
#   'prescribe you narcotics',
#   'help you have a baby',
#   'paying golf fees',
#   'diagnose'],
#  'CapableOf': ['help a sick person',
#   'help a patient',
#   'care for their patients',
#   'answer your questions',
#   'prescribe medicine',
#   'set a broken bone',
#   'visit a patient at home',
#   'explain an illness',
#   'resuscitate someone',
#   "listen to a person's heart",
#   'measure your height',
#   'list the symptoms of a disease',
#   'examine an x-ray',
#   "think he's God",
#   'position a scalpel against the skin',
#   'perfect his golf game',
#   'diagnose a medical problem',
#   'let blood',
#   'help people feel better',
#   'speak to a patient',
#   'earn a lot of money',
#   'study medicine',
#   'heal a sick person',
#   'take a temperature',
#   'recommend dental treatment for some ailments',
#   'prescribe a drug',
#   'provide care',
#   'charge a fee for his services',
#   'prescribe a treatment',
#   'care about her patients',
#   'instruct a nurse',
#   'wear a lab coat',
#   'examine a CAT scan',
#   'touch his patient',
#   'give first aid',
#   'belong to a PPO',
#   'examine you',
#   'case pain with drugs',
#   'listen to his patient',
#   'set a broken arm',
#   'check vital signs',
#   'head a community',
#   'help you maintain good health',
#   'examine an MRI',
#   'service the community',
#   'visit patients on wednesday',
#   'explain a disease',
#   'subject a patient to long waits',
#   'note a symptom',
#   'touch your lymph nodes',
#   'check blood pressure',
#   'perform surgery',
#   'free a patient of a disease',
#   'wear latex gloves',
#   'take a pulse',
#   'charge a lot of money',
#   'examine an ultrasound',
#   'set that leg fracture',
#   'care',
#   'distance himself',
#   'still a patient',
#   'order that medicine',
#   'look at a sick person'],
#  'AtLocation': ["a doctor's office",
#   'the dentist',
#   'a medical school',
#   'a medical office',
#   'a clinic',
#   'an emergency room',
#   'a hospitak',
#   'a nursing home',
#   'the doctor',
#   'the golf course'],
#  'HasProperty': ['well respected'],
#  'Desires': ['you to be healthy',
#   'a big fancy house',
#   'heal the sick',
#   'cure patients']}
