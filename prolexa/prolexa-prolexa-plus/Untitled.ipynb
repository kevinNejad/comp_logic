# %%
import requests

# %%
## Look https://github.com/commonsense/conceptnet5/wiki/Relations 
'''
IsA: car -> vehicle; Chicago -> city
PartOf: gearshit -> car
HasA: bird -> wing; pen -> ink
UsedFor: bridge -> cross water
CapableOf: knife -> cut
AtLocation: butter -> refrigerator; London -> UK
Causes: exercise -> sweat
HasProperty: ice -> cold
Desires: person -> love
CreatedBy: cake -> bake
CausesDesire: having no food -> go to store
MadeOf: bottle -> plastic
'''
relations = ['IsA','PartOf','HasA','UsedFor','CapableOf','AtLocation',
            'Causes','HasProperty','Desires','CreatedBy','CausesDesire','MadeOf']

# %%
API_URI = 'http://api.conceptnet.io/'
EN = 'en'
def get_data(target, relations):
    data={}
    for rel in relations:
        query = 'query?start=/c/{}/{}&rel=/r/{}&limit=1000'.format(EN,target,rel)
        obj = requests.get(API_URI+query).json()
        
        # check if such a relation exist
        if len(obj['edges']) == 0:
            continue
        info = extract_info(obj)
        data[rel] = info
    return data

def extract_info(obj):
    labels = []
    for edge in obj['edges']:
        labels.append(edge['end']['label'])
        
    return labels

# %%
data = get_data('human', relations)

# %%
data
# Out:
# {'IsA': ['a biped',
#   'a synonym for a person',
#   'primate',
#   'hypocrites',
#   'metres scale object',
#   'primate',
#   'a being',
#   'hypocrit',
#   'genus homo',
#   'morally fallible being',
#   'person',
#   'animal'],
#  'PartOf': ['an ecology', 'a human society', 'nature', 'the natural world'],
#  'HasA': ['five fingers on each hand',
#   'one body',
#   'two arms',
#   'two legs and two arms',
#   'muscles',
#   'two ears on their head',
#   'parents',
#   'gone to the moon',
#   'stupidity',
#   'a body and a mind'],
#  'CapableOf': ['think critically',
#   'catch a bus',
#   'torture',
#   'laugh about a joke',
#   'talk to a human',
#   'walk on two legs',
#   'get a job',
#   'think and reason',
#   'laugh at a joke',
#   'have a fever',
#   'go on a date',
#   'have to sleep',
#   'better himself',
#   'taste dish',
#   'cross the road',
#   'sail a sailboat',
#   'drink a cup of coffee',
#   'count money',
#   'say "Hello"',
#   'prepare to do something',
#   'mail to a human',
#   'taste food',
#   'enjoy a performance',
#   'understand new ideas',
#   'shoulder a backpack',
#   'believe that god is real',
#   'dream dreams',
#   'scream',
#   'own material things',
#   'discover how to travel across space',
#   'drink tea',
#   'walk a dog',
#   'wind a toy',
#   'turn away',
#   'stand',
#   'laugh about humor',
#   'form a sentance',
#   'receive a package',
#   'question that God exists',
#   'drink fluids',
#   'break a vow',
#   'need money',
#   'buy an object',
#   'let mistakes occur',
#   'die',
#   'ring a other person',
#   'strike a human',
#   'strike a match',
#   'obtain food in a restaurant',
#   'describe what they have seen',
#   'stand on two legs',
#   'let somebody down',
#   'fool a computer',
#   'step on an insect',
#   'light a candle',
#   'meet another human',
#   'row a boat',
#   'master new skills',
#   'remember an experience',
#   'expect a dog to bark',
#   'view a television series',
#   'have a mental illness',
#   'play a game',
#   'eat spaghetti',
#   'need companionship',
#   'hurt an animal',
#   'write',
#   'smile',
#   'position a thing',
#   'drive a car',
#   'iron clothes',
#   'train an animal',
#   'speak many languages',
#   'take a bath',
#   'master an animal',
#   "value another's life",
#   'lower the curtains',
#   'fast for weeks',
#   'hear a sound',
#   'fire a gun',
#   'drink coffee',
#   'learn whether milk causes prostate cancer'],
#  'AtLocation': ['the school',
#   'homes',
#   'a workplace',
#   'the library',
#   'love',
#   'a park',
#   'a church',
#   'the space shuttle',
#   'jail',
#   'an automobile',
#   'a bus',
#   'a home',
#   'bed',
#   'the solar system',
#   'a bar',
#   'China',
#   'an airport',
#   'an apartment',
#   'a sauna',
#   'a chair',
#   'a theater',
#   'the bathroom',
#   'an office building',
#   'a submarine',
#   'the subway',
#   'an apartment building',
#   'charge',
#   'cemetaries',
#   'a band',
#   'a train',
#   'a hotel',
#   'a bathtub',
#   'a internet cafe',
#   'a village',
#   'motion',
#   'the zoo',
#   'a country',
#   'predicament',
#   'a fun place',
#   'a good mood',
#   'a work enviornment',
#   'control of a machine',
#   'a grave',
#   'heart',
#   "another organism's environment",
#   'a battle',
#   'distress',
#   'austria',
#   'conflict',
#   'any place that is comfortable',
#   'a gboat',
#   'the doctor',
#   'a phone booth',
#   'a Greek tragedy',
#   'an office block',
#   'a shop',
#   'an airplane',
#   'civilisation',
#   'a department store',
#   'Norway',
#   'a war',
#   'outer space',
#   'a plane',
#   'the restroom',
#   'a jeep',
#   'a hous',
#   'all areas of the globe',
#   'New Jersey',
#   "the driver's seat of a car",
#   'the International Space Station',
#   'a cowboy suit',
#   'the surface of the earth',
#   'Michigan',
#   'the bath',
#   'a swimming pool',
#   'a mine',
#   'a gravesite',
#   'a population',
#   'a place of work',
#   'urban area',
#   'nearest house',
#   'command',
#   'the space station',
#   'a farm',
#   'every inhabited place on earth',
#   'a wet suit',
#   'room',
#   'a graveyard',
#   'a red wing jersey',
#   'a dress shop',
#   'a populated city',
#   'Star Trek',
#   'a healthy relationship',
#   'his or her home',
#   'the pool',
#   'a bank',
#   'a train wreck',
#   'the company of other humans',
#   'the way on a crowded street',
#   'a good mook',
#   'downtown',
#   'New York City',
#   'yet another predicament',
#   'a mini van',
#   'a suit',
#   'your own home someday',
#   'deep thought',
#   'a circus',
#   'every part of the world',
#   'a living room',
#   'a stadium',
#   'everywhere on the earth',
#   'a boat',
#   'Mexico',
#   'most places in the world',
#   'a lie',
#   'every crevice of the earth',
#   'emotional distress',
#   'diverse situations',
#   'the theatre',
#   '( on) planet Earth',
#   'a prison',
#   'a coffin',
#   'anywhere on the earth',
#   'office buildings',
#   'group',
#   'a community',
#   'thought',
#   'a factory',
#   'Moscow',
#   'humanity',
#   'a basement',
#   'a redwing jersey',
#   'a motel',
#   'a state',
#   'a canoe',
#   'all forms of the human condition',
#   'a county',
#   'a show',
#   'a mortuary',
#   'a coma',
#   'every place',
#   'an interesting place',
#   'agony',
#   'toil',
#   'automobiles',
#   'pajamas',
#   'society',
#   'a strip club',
#   'turmoil',
#   'any part of the world',
#   'any place you go',
#   'a movie',
#   'control of his destiny',
#   'a spa',
#   'motels',
#   'Detroit',
#   "harm's way",
#   'an aircraft',
#   'cothing',
#   'a cornfield',
#   'New Orleans',
#   'a shopping mall',
#   'a bakery',
#   'an elevator',
#   'any climate',
#   'a moving car',
#   'an urban or suburban area',
#   'an spacecraft',
#   "a friend's house",
#   'conclave',
#   'a family',
#   'Chicago',
#   'pain',
#   'Asia',
#   'most parts of the globe',
#   'many places',
#   'a temperate climate',
#   'a performance',
#   'your own home',
#   'an anatomy textbook',
#   'the mammal family',
#   'a clothing store',
#   'a Wal-Mart Supercenter'],
#  'HasProperty': ['good',
#   'evil',
#   'dangerous to your life',
#   'likely to work in a cubicle'],
#  'Desires': ['money', 'be alone', 'survive at all costs'],
#  'CreatedBy': ['a sperm and an egg', 'parents'],
#  'MadeOf': ['flesh', 'flesh and blood', 'cells', 'bones']}
